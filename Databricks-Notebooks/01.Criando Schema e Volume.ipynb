# %%
"""
Catalog
│
├── Schema
│   │
│   ├── Tabela
│   └── Volume

"""

# %% [markdown]
# Create catalogs:https://learn.microsoft.com/en-us/azure/databricks/catalogs/create-catalog
#
# create-schema:https://learn.microsoft.com/en-us/azure/databricks/schemas/create-schema
#
# Azure Databricks tables concepts:https://learn.microsoft.com/en-us/azure/databricks/tables/tables-concepts
#
# create Volumes:https://learn.microsoft.com/en-us/azure/databricks/volumes/utility-commands
#
# create table:https://learn.microsoft.com/en-us/azure/databricks/sql/language-manual/sql-ref-syntax-ddl-create-table-using
#
#
# comandos SQL:https://docs.databricks.com/aws/en/sql/language-manual/

# %%
spark.sql("CREATE CATALOG IF NOT EXISTS example;")

# %%
# %sql
CREATE CATALOG IF NOT EXISTS example2;

# %%
# deletar catalog
spark.sql("drop CATALOG if exists example cascade;")
spark.sql("drop CATALOG if exists example2 cascade;")

# %%
########## criar 
#criar catalog
#criar schema
#criar tabela
#criar volume

#### deletar 

#drop table
#drop volume
#drop schema
#drop catalog

# %%
#criar catalog
spark.sql("CREATE CATALOG IF NOT EXISTS teste;")

# %%
#criar schema
spark.sql("CREATE SCHEMA IF NOT EXISTS teste.schema1;")

# %%
#criar tabela
spark.sql("CREATE TABLE IF NOT EXISTS teste.schema1.tabela1 (id INT, name STRING) using DELTA;")

# %%
 #criar volume
 spark.sql("CREATE VOLUME IF NOT EXISTS teste.schema1.volume1;")

# %%
#deletar tabela
spark.sql("DROP TABLE IF EXISTS teste.schema1.tabela1")

# %%
#delete volume
spark.sql("DROP VOLUME IF EXISTS teste.schema1.volume1")

# %%
#delete schema
spark.sql("DROP SCHEMA IF EXISTS teste.schema1")

# %%
#deletar catalog
spark.sql("DROP CATALOG IF EXISTS teste cascade")

# %% [markdown]
# Criar ambiente oficial do curso

# %%
# criar arquitetura oficial
spark.sql("CREATE CATALOG IF NOT EXISTS curso_databricks")
spark.sql("CREATE SCHEMA IF NOT EXISTS curso_databricks.aula")
#Tabelas vamos fazer ao decorrer das aulas

spark.sql("""
CREATE VOLUME IF NOT EXISTS curso_databricks.aula.aula_volume
""")
